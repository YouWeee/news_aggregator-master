# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--headless")

driver = webdriver.Chrome(options=chrome_options)
driver.get("https://www.amazon.in/s?k=iphone")
price_xpath = '//*[@id="search"]/div[1]/div[1]/div/span[1]/div[1]/div[3]/div/div/div/div/span/div/div/div/div[2]/div/div/div[3]/div[1]/div/div[1]/div[2]/div[1]/a/span/span[2]'
product_divs = driver.find_elements(By.XPATH, '//div[@data-component-type="s-search-result"]')

for product_div in product_divs:
    try:
        product_title_element = product_div.find_element(By.XPATH, './/h2/a/span')
        product_title = product_title_element.text
        print("Product Title:", product_title)
        
    except:
        print("Product title or price not found for this item.")

driver.quit()
# Out:
# Product Title: Apple iPhone 13 (128GB) - Starlight
# Product Title: Apple iPhone 13 (128GB) - Midnight
# Product Title: Apple iPhone 14 (128 GB) - Midnight
# Product Title: Apple iPhone 15 (128 GB) - Blue
# Product Title: Apple iPhone 13 (128GB) - Pink
# Product Title: Apple iPhone 14 (128 GB) - Purple
# Product Title: Apple iPhone 15 (128 GB) - Green
# Product Title: Apple iPhone 13 (128GB) - Green
# Product Title: Apple iPhone 14 (128 GB) - Starlight
# Product Title: Apple iPhone 15 (256 GB) - Blue
# Product Title: Apple iPhone 15 Pro Max (256 GB) - Blue Titanium
# Product Title: Apple iPhone 15 Plus (128 GB) - Blue
# Product Title: Apple iPhone 15 (128 GB) - Pink
# Product Title: Apple iPhone 15 Plus (128 GB) - Black
# Product Title: Apple iPhone 15 (128 GB) - Black
# Product Title: Apple iPhone 13 (256GB) - Midnight

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--headless")

driver = webdriver.Chrome(options=chrome_options)
driver.get("https://www.amazon.in/s?k=iphone")

product_divs = driver.find_elements(By.XPATH, '//div[@data-component-type="s-search-result"]')

for product_div in product_divs:
    try:
        product_title_element = product_div.find_element(By.XPATH, './/h2/a/span')
        product_title = product_title_element.text
        print("Product Title:", product_title)
        
        price_element = product_div.find_element(By.XPATH, './/span[@class="a-price"]')
        price = price_element.text
        print("Price:", price)
        
    except Exception as e:
        print("Error occurred:", str(e))

driver.quit()
# Out:
# Product Title: Apple iPhone 13 (128GB) - Starlight
# Price: ₹49,299
# Product Title: Apple iPhone 13 (128GB) - Midnight
# Price: ₹49,299
# Product Title: Apple iPhone 14 (128 GB) - Midnight
# Price: ₹58,999
# Product Title: Apple iPhone 15 (128 GB) - Blue
# Price: ₹73,100
# Product Title: Apple iPhone 13 (128GB) - Pink
# Price: ₹49,999
# Product Title: Apple iPhone 14 (128 GB) - Purple
# Price: ₹58,999
# Product Title: Apple iPhone 15 (128 GB) - Green
# Price: ₹73,100
# Product Title: Apple iPhone 13 (128GB) - Green
# Price: ₹49,999
# Product Title: Apple iPhone 14 (128 GB) - Starlight
# Price: ₹58,999
# Product Title: Apple iPhone 15 (256 GB) - Blue
# Price: ₹82,600
# Product Title: Apple iPhone 15 Pro Max (256 GB) - Blue Titanium
# Price: ₹1,48,900
# Product Title: Apple iPhone 15 Plus (128 GB) - Blue
# Price: ₹82,600
# Product Title: Apple iPhone 15 (128 GB) - Pink
# Price: ₹73,100
# Product Title: Apple iPhone 15 Plus (128 GB) - Black
# Price: ₹82,600
# Product Title: Apple iPhone 15 (128 GB) - Black
# Price: ₹73,100
# Product Title: Apple iPhone 13 (256GB) - Midnight
# Price: ₹59,999

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

def scrape_amazon_page(url):
    chrome_options = webdriver.ChromeOptions()
    chrome_options.add_argument("--headless")

    driver = webdriver.Chrome(options=chrome_options)
    driver.get(url)

    product_divs = driver.find_elements(By.XPATH, '//div[@data-component-type="s-search-result"]')

    for product_div in product_divs:
        try:
            product_title_element = product_div.find_element(By.XPATH, './/h2/a/span')
            product_title = product_title_element.text
            print("Product Title:", product_title)

            price_element = product_div.find_element(By.XPATH, './/span[@class="a-price"]')
            price = price_element.text
            print("Price:", price)

        except Exception as e:
            print("Error occurred:", str(e))

    driver.quit()

num_pages = 5  

for page_num in range(1, num_pages + 1):
    url = f"https://www.amazon.in/s?k=iphone&qid=1713807378&ref=sr_pg_{page_num}"
    print("Scraping page:", page_num)
    scrape_amazon_page(url)
    time.sleep(2)
# Out:
# Scraping page: 1
# Product Title: Apple iPhone 13 (128GB) - Starlight
# Price: ₹49,299
# Product Title: Apple iPhone 13 (128GB) - Midnight
# Price: ₹49,299
# Product Title: Apple iPhone 14 (128 GB) - Midnight
# Price: ₹58,999
# Product Title: Apple iPhone 15 (128 GB) - Blue
# Price: ₹73,100
# Product Title: Apple iPhone 13 (128GB) - Pink
# Price: ₹49,999
# Product Title: Apple iPhone 14 (128 GB) - Purple
# Price: ₹58,999
# Product Title: Apple iPhone 15 (128 GB) - Green
# Price: ₹73,100
# Product Title: Apple iPhone 13 (128GB) - Green
# Price: ₹49,999
# Product Title: Apple iPhone 14 (128 GB) - Starlight
# Price: ₹58,999
# Product Title: Apple iPhone 15 (256 GB) - Blue
# Price: ₹82,600
# Product Title: Apple iPhone 15 Pro Max (256 GB) - Blue Titanium
# Price: ₹1,48,900
# Product Title: Apple iPhone 15 Plus (128 GB) - Blue
# Price: ₹82,600
# Product Title: Apple iPhone 15 (128 GB) - Pink
# Price: ₹73,100
# Product Title: Apple iPhone 15 Plus (128 GB) - Black
# Price: ₹82,600
# Product Title: Apple iPhone 15 (128 GB) - Black
# Price: ₹73,100
# Product Title: Apple iPhone 13 (256GB) - Midnight
# Price: ₹59,999
# Scraping page: 2
# Product Title: Apple iPhone 13 (128GB) - Starlight
# Price: ₹49,299
# Product Title: Apple iPhone 13 (128GB) - Midnight
# Price: ₹49,299
# Product Title: Apple iPhone 14 (128 GB) - Midnight
# Price: ₹58,999
# Product Title: Apple iPhone 15 (128 GB) - Blue
# Price: ₹73,100
# Product Title: Apple iPhone 13 (128GB) - Pink
# Price: ₹49,999
# Product Title: Apple iPhone 14 (128 GB) - Purple
# Price: ₹58,999
# Product Title: Apple iPhone 15 (128 GB) - Green
# Price: ₹73,100
# Product Title: Apple iPhone 13 (128GB) - Green
# Price: ₹49,999
# Product Title: Apple iPhone 14 (128 GB) - Starlight
# Price: ₹58,999
# Product Title: Apple iPhone 15 (256 GB) - Blue
# Price: ₹82,600
# Product Title: Apple iPhone 15 Pro Max (256 GB) - Blue Titanium
# Price: ₹1,48,900
# Product Title: Apple iPhone 15 Plus (128 GB) - Blue
# Price: ₹82,600
# Product Title: Apple iPhone 15 (128 GB) - Pink
# Price: ₹73,100
# Product Title: Apple iPhone 15 Plus (128 GB) - Black
# Price: ₹82,600
# Product Title: Apple iPhone 15 (128 GB) - Black
# Price: ₹73,100
# Product Title: Apple iPhone 13 (256GB) - Midnight
# Price: ₹59,999
# Scraping page: 3
# Product Title: Apple iPhone 13 (128GB) - Starlight
# Price: ₹49,299
# Product Title: Apple iPhone 13 (128GB) - Midnight
# Price: ₹49,299
# Product Title: Apple iPhone 14 (128 GB) - Midnight
# Price: ₹58,999
# Product Title: Apple iPhone 15 (128 GB) - Blue
# Price: ₹73,100
