# %%
from newspaper import Article
import newspaper

# %%
url='https://indianexpress.com'

# %%
my_article=Article(url,language='en')

# %%
my_article.download()

# %%
print(my_article.html)
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns:og="https://ogp.me/ns#">
# <head>
# <meta charset="UTF-8">
# 	<meta name="viewport" content="width=990" />
# ...

# %%
my_article.parse()

# %%
print('Title:',my_article.title)
print('Publishing Date:',my_article.publish_date)
# Out:
# Title: Latest News Today: Breaking News and Top Headlines from India, Entertainment, Business, Politics and Sports
# Publishing Date: None

# %%
my_article.nlp()
print('summary:',my_article.summary)
# Out:
# summary: India Updated: March 10, 2024 22:39 ISTThe unexpected decision of TMC to nominate ex-cricketer Yusuf Pathan as its Lok Sabha candidate from West Bengal has sparked a debate.
# Bengal Congress chief Adhir Chowdhury accused TMC of using Pathan to benefit BJP and send a message to PM Modi.
# He suggested other options for Pathan's nomination, while Pathan himself expressed gratitude and was supported by his brother Irfan Pathan.

# %%
bbc=newspaper.build('https://www.bbc.com/news')

# %%
for article in bbc.articles:
     print(article.url)

# %%
for category in bbc.category_urls():
     print(category)
# Out:
# https://www.bbc.com/news
# https://www.bbc.com/sport
# https://www.bbc.co.uk
# https://www.bbc.com
# https://www.bbc.com/news

# %%
import newspaper

bbc = newspaper.build('https://www.thehindu.com/')

# Get titles and summaries of all articles
for article in bbc.articles:
    article.download()
    article.parse()
    print("Title:", article.title)
    my_article.nlp
    print("Summary:", article.summary)
    print()
